# %%
import pandas
import numpy as np
import requests

# %%
# Create a new set of 2,000 random latitudes and longitudes.

#latitudes
latitudes=np.random.uniform(-90.000, 90.000, size=2000)

#longitudes
longitudes=np.random.uniform(-180.000, 180.000, size=2000)
longitudes
# Out:
# array([-160.32394902,  -38.85916128,  -59.0464258 , ...,  111.93119783,
#         -12.59479363,  134.70097058])

# %%
# Get the nearest city using the citipy module.
from citipy import citipy

#initalize cities list
nearest_cities=[]

#loop through lats and longs
for i in range(len(latitudes)):
    nearest_city = citipy.nearest_city(latitudes[i],longitudes[i]).city_name
    if nearest_city not in nearest_cities:
        nearest_cities.append(nearest_city) 

nearest_cities
# Out:
# ['hilo',
#  'ribeira grande',
#  'ushuaia',
#  'mitsamiouli',
#  'rikitea',
#  'mys shmidta',
#  'eregli',
#  'doha',
#  'east london',
#  'bambous virieux',
#  'puerto ayora',
#  'fez',
#  'albany',
#  'atuona',
#  'iqaluit',
#  'busselton',
#  'mar del plata',
#  'amderma',
#  'avarua',
#  'adrar',
#  'kapaa',
#  'bredasdorp',
#  'asau',
#  'georgetown',
#  'mataura',
#  'new norfolk',
#  'hithadhoo',
#  'depalpur',
#  'karatau',
#  'jiddah',
#  'miri',
#  'lavumisa',
#  'butaritari',
#  'luderitz',
#  'klaksvik',
#  'vaini',
#  'kodiak',
#  'holme',
#  'aklavik',
#  'bengkulu',
#  'souillac',
#  'saint-philippe',
#  'seoul',
#  'portel',
#  'zhurivka',
#  'sao felix do xingu',
#  'college',
#  'garowe',
#  'barrow',
#  'chokurdakh',
#  'punta arenas',
#  'khatanga',
#  'dondo',
#  'hobart',
#  'maningrida',
#  'roald',
#  'hofn',
#  'tsihombe',
#  'usinsk',
#  'ancud',
#  'yellowknife',
#  'lebu',
#  'severo-kurilsk',
#  'thompson',
#  'san carlos de bariloche',
#  'vila franca do campo',
#  'tasiilaq',
#  'lavrentiya',
#  'taolanaro',
#  'ketchikan',
#  'norman wells',
#  'faya',
#  'hartland',
#  'carnarvon',
#  'sheltozero',
#  'lompoc',
#  'dubenskiy',
#  'jamestown',
#  'cape town',
#  'flinders',
#  'tanout',
#  'faanui',
#  'samagaltay',
#  'mossendjo',
#  'karaul',
#  'mount gambier',
#  'codrington',
#  'yaroslavl',
#  'san quintin',
#  'tilichiki',
#  'santa',
#  'beisfjord',
#  'fort-shevchenko',
#  'cardonal',
#  'saint george',
#  'isangel',
#  'yaan',
#  'ilulissat',
#  'strathmore',
#  'deputatskiy',
#  'marzuq',
#  'illoqqortoormiut',
#  'saskylakh',
#  'sao joao da barra',
#  'hermanus',
#  'beroroha',
#  'labuan',
#  'alofi',
#  'ponta delgada',
#  'beringovskiy',
#  'suvorovo',
#  'bethel',
#  'tuktoyaktuk',
#  'rawson',
#  'bilibino',
#  'kruisfontein',
#  'kirakira',
#  'samusu',
#  'saleaula',
#  'nhulunbuy',
#  'manchester',
#  'southbridge',
#  'saldanha',
#  'burley',
#  'kuala lipis',
#  'port elizabeth',
#  'alta floresta',
#  'victoria',
#  'cabo san lucas',
#  'la reforma',
#  'portland',
#  'neryungri',
#  'vaitupu',
#  'valdosta',
#  'san vicente',
#  'sechura',
#  'ahipara',
#  'barentsburg',
#  'tadine',
#  'bay roberts',
#  'turukhansk',
#  'romny',
#  'spearfish',
#  'bluff',
#  'coolum beach',
#  'tura',
#  'port keats',
#  'qaanaaq',
#  'whitehorse',
#  'cayenne',
#  'port macquarie',
#  'sheopur',
#  'afyonkarahisar',
#  'znamenskoye',
#  'novyy urengoy',
#  'cabrero',
#  'kanchanaburi',
#  'mato verde',
#  'newport',
#  'sibolga',
#  'buala',
#  'necochea',
#  'olafsvik',
#  'comodoro rivadavia',
#  'henties bay',
#  'tiassale',
#  'paamiut',
#  'sorong',
#  'finnsnes',
#  'barcelos',
#  'pangkalanbuun',
#  'namatanai',
#  'marathon',
#  'angoram',
#  'porto novo',
#  'tiksi',
#  'mandalgovi',
#  'salalah',
#  'boguchany',
#  'hastings',
#  'najran',
#  'naliya',
#  'sembakung',
#  'grand island',
#  'port alfred',
#  'gladstone',
#  'san patricio',
#  'tlamacazapa',
#  'mana',
#  'clyde river',
#  'cidreira',
#  'beloha',
#  'utiel',
#  'chulman',
#  'lorengau',
#  'kununurra',
#  'fortuna',
#  'vestmannaeyjar',
#  'cotonou',
#  'namwala',
#  'sentyabrskiy',
#  'ust-nera',
#  'talnakh',
#  'tamandare',
#  'amravati',
#  'ponta do sol',
#  'barranca',
#  'mosquera',
#  'shenjiamen',
#  'tazovskiy',
#  'baghdad',
#  'ulagan',
#  'griffin',
#  'yanagawa',
#  'ishigaki',
#  'balabac',
#  'arraial do cabo',
#  'dikson',
#  'katsuura',
#  'haines junction',
#  'yeppoon',
#  'kaitangata',
#  'vanino',
#  'ixtapa',
#  'hasaki',
#  'andenes',
#  'puerto colombia',
#  'touros',
#  'kamenka',
#  'bargal',
#  'xining',
#  'el balyana',
#  'barra patuca',
#  'nikolskoye',
#  'provideniya',
#  'castro',
#  'deshna',
#  'samalaeulu',
#  'kawalu',
#  'jian',
#  'taksimo',
#  'tchollire',
#  'esperance',
#  'griffith',
#  'nizhneyansk',
#  'padang',
#  'lahaina',
#  'dumas',
#  'malmesbury',
#  'erzin',
#  'inderborskiy',
#  'tyukhtet',
#  'ligayan',
#  'dudinka',
#  'igarka',
#  'gilgit',
#  'netarhat',
#  'alyangula',
#  'te anau',
#  'hamilton',
#  'mahebourg',
#  'nanortalik',
#  'umzimvubu',
#  'guiratinga',
#  'marienburg',
#  'nome',
#  'ilhabela',
#  'clonakilty',
#  'yialos',
#  'cherskiy',
#  'hurghada',
#  'mrirt',
#  'coahuayana',
#  'harper',
#  'tynda',
#  'bagdarin',
#  'pedro ii',
#  'chuy',
#  'constitucion',
#  'yabrud',
#  'grand river south east',
#  'adwa',
#  'ruwi',
#  'okhotsk',
#  'sturgis',
#  'teknaf',
#  'sorland',
#  'yeletskiy',
#  'kungurtug',
#  'tumannyy',
#  'atambua',
#  'coquimbo',
#  'manzanillo',
#  'gondanglegi',
#  'yulara',
#  'devonport',
#  'upernavik',
#  'geraldton',
#  'mbanza-ngungu',
#  'fare',
#  'karmana',
#  'alekseyevka',
#  'arman',
#  'ayr',
#  'port blair',
#  'airai',
#  'kadykchan',
#  'longyearbyen',
#  'shuangyang',
#  'samarai',
#  'mehamn',
#  'ayan',
#  'ruidoso',
#  'bonavista',
#  'atar',
#  'labytnangi',
#  'halifax',
#  'mazarron',
#  'port hedland',
#  'fairbanks',
#  'srandakan',
#  'bocas del toro',
#  'goderich',
#  'santa barbara',
#  'zaysan',
#  'sitka',
#  'torbay',
#  'yar-sale',
#  'marsa matruh',
#  'naze',
#  'ostrovnoy',
#  'aketi',
#  'formoso do araguaia',
#  'neiafu',
#  'meyungs',
#  'dunedin',
#  'kampong thum',
#  'westport',
#  'baiquan',
#  'la cruz',
#  'gat',
#  'hamadan',
#  'kelso',
#  'maragogi',
#  'camana',
#  'harer',
#  'oranjemund',
#  'kesennuma',
#  'bell ville',
#  'pevek',
#  'contamana',
#  'grand gaube',
#  'kondopoga',
#  'vila',
#  'pozo colorado',
#  'tuatapere',
#  'attawapiskat',
#  'cabra',
#  'minab',
#  'matane',
#  'lasa',
#  'lewistown',
#  'kachikau',
#  'luis correia',
#  'tolaga bay',
#  'strezhevoy',
#  'zhoucheng',
#  'porto de moz',
#  'kenai',
#  'russell',
#  'mareeba',
#  'bonthe',
#  'louisbourg',
#  'luanda',
#  'mackenzie',
#  'fort nelson',
#  'petropavlovsk-kamchatskiy',
#  'udachnyy',
#  'casambalangan',
#  'paradwip',
#  'bowen',
#  'coulihaut',
#  'deniliquin',
#  'saint-pierre',
#  'warqla',
#  'tulun',
#  'karratha',
#  'kieta',
#  'mayo',
#  'syracuse',
#  'zhigansk',
#  'kristiinankaupunki',
#  'yarada',
#  'campbellton',
#  'pisco',
#  'san luis',
#  'sicamous',
#  'timizart',
#  'luebo',
#  'axim',
#  'namangan',
#  'uyuni',
#  'capaci',
#  'quelimane',
#  'urumqi',
#  'dir',
#  'aurillac',
#  'chivay',
#  'aberystwyth',
#  'rio gallegos',
#  'nuuk',
#  'taunggyi',
#  'dingle',
#  'butka',
#  'kahului',
#  'manggar',
#  'broken hill',
#  'sarai naurang',
#  'barbar',
#  'yunjinghong',
#  'sao filipe',
#  'tomelloso',
#  'belushya guba',
#  'pak phanang',
#  'kautokeino',
#  'pleasanton',
#  'spring',
#  'sovetskiy',
#  'along',
#  'mastic beach',
#  'umba',
#  'awbari',
#  'aktau',
#  'balkanabat',
#  'laguna',
#  'slavuta',
#  'scottsbluff',
#  'oistins',
#  'mocambique',
#  'karamea',
#  'bathsheba',
#  'talara',
#  'shimoda',
#  'shafranovo',
#  'takoradi',
#  'sola',
#  'spring valley',
#  'marcona',
#  'carutapera',
#  'kamenskoye',
#  'port hardy',
#  'lagunas',
#  'vila velha',
#  'mazamari',
#  'tessalit',
#  'nerja',
#  'komsomolskiy',
#  'thunder bay',
#  'pemangkat',
#  'chadiza',
#  'rock sound',
#  'kavieng',
#  'san buenaventura',
#  'watertown',
#  'opuwo',
#  'yermish',
#  'kuala terengganu',
#  'sabzevar',
#  'matiri',
#  'bintulu',
#  'riyadh',
#  'narsaq',
#  'vardo',
#  'satitoa',
#  'muros',
#  'saint-augustin',
#  'richards bay',
#  'ust-ishim',
#  'dolores',
#  'grand centre',
#  'ust-kan',
#  'eyl',
#  'panaba',
#  'polunochnoye',
#  'grand-santi',
#  'sahbuz',
#  'diamantino',
#  'manicore',
#  'kempsey',
#  'leningradskiy',
#  'hinundayan',
#  'tripoli',
#  'rio grande',
#  'gromiljak',
#  'viedma',
#  'siutu',
#  'araouane',
#  'auki',
#  'walvis bay',
#  'itacare',
#  'trinidad',
#  'svobodnyy',
#  'saiki',
#  'sobolevo',
#  'basavana bagevadi',
#  'danilovka',
#  'north myrtle beach',
#  'lidkoping',
#  'vanavara',
#  'suoyarvi',
#  'novopokrovka',
#  'rocha',
#  'hambantota',
#  'zabol',
#  'banikoara',
#  'beyneu',
#  'wanlaweyn',
#  'bandarbeyla',
#  'nago',
#  'ekhabi',
#  'lamu',
#  'caravelas',
#  'vanimo',
#  'havre-saint-pierre',
#  'williston',
#  'waipawa',
#  'manokwari',
#  'eydhafushi',
#  'mozhga',
#  'vorozhba',
#  'nouadhibou',
#  'krasnoselkup',
#  'wanaka',
#  'guerrero negro',
#  'santa cruz do capibaribe',
#  'sterling',
#  'anadyr',
#  'beasain',
#  'mallaig',
#  'arandis',
#  'monticello',
#  'egvekinot',
#  'los llanos de aridane',
#  'langham',
#  'dhidhdhoo',
#  'kushima',
#  'lolua',
#  'warragul',
#  'gra liyia',
#  'coruripe',
#  'san carlos',
#  'asino',
#  'kango',
#  'mount isa',
#  'kortkeros',
#  'la palma',
#  'tunduru',
#  'tautira',
#  'lapy',
#  'nicoya',
#  'katangli',
#  'denpasar',
#  'tucurui',
#  'namibe',
#  'altus',
#  'zyryanka',
#  'waingapu',
#  'vao',
#  'dezhou',
#  'valday',
#  'killarney',
#  'khani',
#  'cabedelo',
#  'kavaratti',
#  'moroni',
#  'changli',
#  'thurso',
#  'xique-xique',
#  'beidao',
#  'mergui',
#  'abapo',
#  'mineiros',
#  'santa isabel do rio negro',
#  'sovetskaya gavan',
#  'kiunga',
#  'kedougou',
#  'shepsi',
#  'muzhi',
#  'amapa',
#  'aksarka',
#  'kachiry',
#  'tahe',
#  'bumba',
#  'svinninge',
#  'taburi',
#  'labuhan',
#  'tabou',
#  'lanas',
#  'berbera',
#  'tomatlan',
#  'keetmanshoop',
#  'villa maria',
#  'nelson bay',
#  'ola',
#  'lyubech',
#  'sakakah',
#  'kalmunai',
#  'bethal',
#  'lazaro cardenas',
#  'bandar-e anzali',
#  'siocon',
#  'hobyo',
#  'talaya',
#  'launceston',
#  'northfield',
#  'wagar',
#  'moose factory',
#  'bol',
#  'eresos',
#  'kysyl-syr',
#  'ferkessedougou',
#  'almaznyy',
#  'konstantinovka',
#  'ostersund',
#  'san cristobal',
#  'teguldet',
#  'areosa',
#  'gilbues',
#  'mildura',
#  'hirado',
#  'araguaina',
#  'mrakovo',
#  'rosita',
#  'ust-kuyga',
#  'yerofey pavlovich',
#  'ballina',
#  'russkaya polyana',
#  'thayetmyo',
#  'aykhal',
#  'saint anthony',
#  'mayumba',
#  'aksay',
#  'brae',
#  'nabire',
#  'palaikastron',
#  'zhanaozen',
#  'oksfjord',
#  'alice springs',
#  'queanbeyan',
#  'lisala',
#  'braesti',
#  'qaqortoq',
#  'avera',
#  'asyut',
#  'mwingi',
#  'kuhdasht',
#  'filadelfia',
#  'libenge',
#  'kousseri',
#  'morondava',
#  'cravo norte',
#  'jalu',
#  'noumea',
#  'peace river',
#  'divnogorsk',
#  'tabialan',
#  'abha',
#  'trelew',
#  'manama',
#  'artyk',
#  'treinta y tres',
#  'santo antonio do ica',
#  'petrozavodsk',
#  'kuito',
#  'tual',
#  'port augusta',
#  'skalistyy',
#  'visnes',
#  'sungaipenuh',
#  'the pas',
#  'sumiswald',
#  'waverly',
#  'garmsar',
#  'butwal',
#  'mercedes',
#  'timbiqui',
#  'redmond',
#  'guarapari',
#  'turayf',
#  'srednekolymsk',
#  'shahr-e babak',
#  'abu samrah',
#  'sulina',
#  'gazli',
#  'sisimiut',
#  'opelika',
#  'nishihara',
#  'yugo-kamskiy',
#  'camocim',
#  'muta',
#  'belaya gora',
#  'choix',
#  'tabuk',
#  'rio claro',
#  'jizan',
#  'palabuhanratu',
#  'pringsewu',
#  'natal',
#  'sagaing',
#  'kalikapur',
#  'mwene-ditu',
#  'agadir',
#  'roman',
#  'lyuban',
#  'isla mujeres',
#  'kropotkin',
#  'nileshwar',
#  'hervey bay',
#  'teguise',
#  'sun valley',
#  'vengerovo',
#  'port hawkesbury',
#  'broome',
#  'skibbereen',
#  'cockburn town',
#  'yima',
#  'kopervik',
#  'saint-francois',
#  'omoa',
#  'linhares',
#  'bershet',
#  'lola',
#  'haicheng',
#  'prince rupert',
#  'nautla',
#  'tortoli',
#  'puri',
#  'port-gentil',
#  'chivolo',
#  'acajutla',
#  'ust-kamchatsk',
#  'arkhangelskoye',
#  'aranda de duero',
#  'miraflores',
#  'yarmouth',
#  'yamasaki']
