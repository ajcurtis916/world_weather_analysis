# %%
import pandas as pd
import numpy as np
import requests
from datetime import datetime
import time

# %%
# Create a new set of 2,000 random latitudes and longitudes.

#latitudes
latitudes=np.random.uniform(-90.000, 90.000, size=2000)

#longitudes
longitudes=np.random.uniform(-180.000, 180.000, size=2000)
longitudes
# Out:
# array([-142.05292171, -161.1385    ,  -73.33781841, ...,  -99.02276075,
#        -117.46101596,   11.74739774])

# %%
# Get the nearest city using the citipy module.
from citipy import citipy

#initalize cities list
nearest_cities=[]

#loop through lats and longs
for i in range(len(latitudes)):
    nearest_city = citipy.nearest_city(latitudes[i],longitudes[i]).city_name
    if nearest_city not in nearest_cities:
        nearest_cities.append(nearest_city) 

nearest_cities
# Out:
# ['atuona',
#  'barrow',
#  'qaanaaq',
#  'punta arenas',
#  'liwale',
#  'hamilton',
#  'east london',
#  'mar del plata',
#  'nyaunglebin',
#  'jamestown',
#  'oranjemund',
#  'busselton',
#  'taolanaro',
#  'roald',
#  'moerai',
#  'san quintin',
#  'butaritari',
#  'hastings',
#  'aksarka',
#  'komsomolskiy',
#  'mataura',
#  'vaini',
#  'broome',
#  'avarua',
#  'severo-kurilsk',
#  'koosa',
#  'killybegs',
#  'vaitupu',
#  'vila velha',
#  'hithadhoo',
#  'arraial do cabo',
#  'harer',
#  'narsaq',
#  'kapaa',
#  'ushuaia',
#  'hermanus',
#  'camana',
#  'leh',
#  'thanh hoa',
#  'port alfred',
#  'mount isa',
#  'ostrovnoy',
#  'hobart',
#  'xichang',
#  'mandalgovi',
#  'new norfolk',
#  'namibe',
#  'halalo',
#  'ketchikan',
#  'mangrol',
#  'alofi',
#  'yellowknife',
#  'viligili',
#  'keti bandar',
#  'nikolskoye',
#  'lansdale',
#  'attawapiskat',
#  'aksha',
#  'sur',
#  'steamboat springs',
#  'hami',
#  'dezful',
#  'sawakin',
#  'albany',
#  'vardo',
#  'sola',
#  'hualmay',
#  'hilo',
#  'plettenberg bay',
#  'kon tum',
#  'minab',
#  'rikitea',
#  'manggar',
#  'aflu',
#  'antofagasta',
#  'cidreira',
#  'khotyn',
#  'ust-kulom',
#  'hovd',
#  'provideniya',
#  'yerbogachen',
#  'port elizabeth',
#  'kyzyl-mazhalyk',
#  'udachnyy',
#  'sherlovaya gora',
#  'khatanga',
#  'aklavik',
#  'lethem',
#  'belushya guba',
#  'bonthe',
#  'norman wells',
#  'chokurdakh',
#  'xiaoweizhai',
#  'cabo san lucas',
#  'coquimbo',
#  'gorontalo',
#  'suao',
#  'asfi',
#  'chicama',
#  'grand gaube',
#  'ancud',
#  'mapiri',
#  'sitka',
#  'bacuit',
#  'bluff',
#  'cape town',
#  'rincon',
#  'iquique',
#  'illapel',
#  'tumannyy',
#  'karratha',
#  'sentyabrskiy',
#  'port lincoln',
#  'coihaique',
#  'georgetown',
#  'sakaiminato',
#  'petropavlovsk-kamchatskiy',
#  'amderma',
#  'harper',
#  'portland',
#  'awallan',
#  'batagay-alyta',
#  'katherine',
#  'kolyvan',
#  'lenger',
#  'nizhneyansk',
#  'fortuna',
#  'esperance',
#  'mizdah',
#  'bolungarvik',
#  'carnarvon',
#  'wynyard',
#  'mount gambier',
#  'puerto ayora',
#  'port keats',
#  'luderitz',
#  'san vicente',
#  'rawson',
#  'kaitangata',
#  'kamra',
#  'piacabucu',
#  'abu zabad',
#  'port-gentil',
#  'saldanha',
#  'bontang',
#  'rio grande',
#  'illoqqortoormiut',
#  'isla mujeres',
#  'north bend',
#  'ilulissat',
#  'klaksvik',
#  'inverell',
#  'nanhai',
#  'barentsburg',
#  'pirovskoye',
#  'saleaula',
#  'riyadh',
#  'lebu',
#  'luanda',
#  'deshnok',
#  'bambous virieux',
#  'bayir',
#  'morondava',
#  'namatanai',
#  'henderson',
#  'faya',
#  'sinnamary',
#  'koungou',
#  'kibaya',
#  'batticaloa',
#  'westlock',
#  'nemuro',
#  'hasaki',
#  'castro',
#  'atar',
#  'kirakira',
#  'marzuq',
#  'narasannapeta',
#  'inta',
#  'saskylakh',
#  'syumsi',
#  'bambanglipuro',
#  'inhambane',
#  'tasiilaq',
#  'haines junction',
#  'lavrentiya',
#  'codrington',
#  'cascais',
#  'anadyr',
#  'meyungs',
#  'airai',
#  'nome',
#  'kavaratti',
#  'faanui',
#  'kviteseid',
#  'arkhangelos',
#  'prince rupert',
#  'tiksi',
#  'bombay',
#  'lumeje',
#  'fomboni',
#  'tezu',
#  'kodiak',
#  'odlabari',
#  'bonavista',
#  'tsihombe',
#  'nushki',
#  'utiroa',
#  'santiago',
#  'katsuura',
#  'ampanihy',
#  'macaboboni',
#  'cumaribo',
#  'port hardy',
#  'bredasdorp',
#  'nanortalik',
#  'ust-tsilma',
#  'jacqueville',
#  'kalmar',
#  'rawannawi',
#  'siocon',
#  'upernavik',
#  'meadow lake',
#  'dandong',
#  'taksimo',
#  'gornopravdinsk',
#  'byron bay',
#  'port-de-paix',
#  'dikson',
#  'honiara',
#  'torbay',
#  'saint-philippe',
#  'tigil',
#  'emerald',
#  'bosaso',
#  'baruun-urt',
#  'sao filipe',
#  'simao',
#  'ciras',
#  'pacifica',
#  'cherskiy',
#  'kupang',
#  'salalah',
#  'nouadhibou',
#  'sinegorye',
#  'kharhial',
#  'dauriya',
#  'chuy',
#  'charters towers',
#  'kavieng',
#  'santa cruz',
#  'ayagoz',
#  'corinto',
#  'poum',
#  'ober-ramstadt',
#  'te anau',
#  'rungata',
#  'kikwit',
#  'mehamn',
#  'port moresby',
#  'fukue',
#  'diamantino',
#  'longyearbyen',
#  'saint pete beach',
#  'presidencia roque saenz pena',
#  'isangel',
#  'dunedin',
#  'masuda',
#  'alcains',
#  'mys shmidta',
#  'waddan',
#  'albanel',
#  'micheweni',
#  'bardiyah',
#  'obluche',
#  'santa isabel do rio negro',
#  'ponta do sol',
#  'tuktoyaktuk',
#  'bengkulu',
#  'axim',
#  'richards bay',
#  'roma',
#  'kargasok',
#  'jijiga',
#  'hendijan',
#  'leningradskiy',
#  'saryshagan',
#  'gat',
#  'pahrump',
#  'fairmont',
#  'palmer',
#  'mahebourg',
#  'san cristobal',
#  'siuna',
#  'marawi',
#  'limbang',
#  'fosforitnyy',
#  'bridgetown',
#  'pangnirtung',
#  'medea',
#  'samana',
#  'dongning',
#  'bowen',
#  'mednogorsk',
#  'praia da vitoria',
#  'mao',
#  'ribeira grande',
#  'elko',
#  'marrakesh',
#  'karaton',
#  'ejido',
#  'half moon bay',
#  'warqla',
#  'macherla',
#  'usinsk',
#  'kargil',
#  'russell',
#  'grand river south east',
#  'lengshuitan',
#  'safita',
#  'san patricio',
#  'winnemucca',
#  'dubbo',
#  'husavik',
#  'bogovarovo',
#  'tuatapere',
#  'verkhoyansk',
#  'pokosnoye',
#  'alcantara',
#  'formiga',
#  'teya',
#  'huoqiu',
#  'kollam',
#  'berlevag',
#  'pisco',
#  'raga',
#  'ulaangom',
#  'garissa',
#  'rondonopolis',
#  'challapata',
#  'uk',
#  'fare',
#  'guangyuan',
#  'xinyang',
#  'smithers',
#  'mecca',
#  'thompson',
#  'waingapu',
#  'kununurra',
#  'krasnorechenskiy',
#  'granadilla de abona',
#  'port blair',
#  'saint george',
#  'bandarbeyla',
#  'grand-lahou',
#  'avera',
#  'mahaicony',
#  'sorvag',
#  'pevek',
#  'skibbereen',
#  'qingdao',
#  'macapa',
#  'cayenne',
#  'chitungwiza',
#  'ugoofaaru',
#  'butembo',
#  'kiama',
#  'ambam',
#  'srandakan',
#  'mayumba',
#  'deputatskiy',
#  'atakpame',
#  'najran',
#  'mildura',
#  'xinzhi',
#  'cam pha',
#  'zlotoryja',
#  'banmo',
#  'nouakchott',
#  'moyale',
#  'sao joao da barra',
#  'eydhafushi',
#  'semey',
#  'san andres',
#  'marv dasht',
#  'parana',
#  'saquena',
#  'brodick',
#  'eureka',
#  'mogochin',
#  'vanavara',
#  'bilibino',
#  'farmington',
#  'belaya gora',
#  'port macquarie',
#  'andevoranto',
#  'hofn',
#  'ankara',
#  'lompoc',
#  'meulaboh',
#  'maragogi',
#  'gubkinskiy',
#  'puerto madryn',
#  'saint-denis',
#  'kuusamo',
#  'gimli',
#  'izumo',
#  'itoman',
#  'kenai',
#  'fairbanks',
#  'oytal',
#  'tallahassee',
#  'whitianga',
#  'barentu',
#  'cotonou',
#  'darlawn',
#  'constantine',
#  'brae',
#  'gorom-gorom',
#  'lynn haven',
#  'lazaro cardenas',
#  'fredericksburg',
#  'porvoo',
#  'nelson bay',
#  'cyangugu',
#  'blenheim',
#  'constitucion',
#  'vanderbijlpark',
#  'tumpat',
#  'saint-paul',
#  'kahului',
#  'carepa',
#  'zbarazh',
#  'ahipara',
#  'presidente medici',
#  'thinadhoo',
#  'lumsden',
#  'magelang',
#  'mahibadhoo',
#  'lolua',
#  'kakonko',
#  'karamay',
#  'olafsvik',
#  'peniche',
#  'tahe',
#  'kano',
#  'zyryanovsk',
#  'high level',
#  'naze',
#  'talnakh',
#  'gizo',
#  'kokopo',
#  'smidovich',
#  'college',
#  'palabuhanratu',
#  'watsa',
#  'zachagansk',
#  'bathsheba',
#  'los llanos de aridane',
#  'dianopolis',
#  'kearney',
#  'aripuana',
#  'wairoa',
#  'tabuk',
#  'fonte boa',
#  'souillac',
#  'vanimo',
#  'hauterive',
#  'jumla',
#  'san matias',
#  'ishigaki',
#  'xining',
#  'belmonte',
#  'stephenville',
#  'beringovskiy',
#  'phek',
#  'caborca',
#  'kloulklubed',
#  'leavenworth',
#  'chenghai',
#  'stornoway',
#  'bethel',
#  'moose factory',
#  'balezino',
#  'sampit',
#  'solsvik',
#  'angoche',
#  'adrar',
#  'banjar',
#  'worthing',
#  'mugur-aksy',
#  'smirnykh',
#  'windhoek',
#  'olinda',
#  'tautira',
#  'dicabisagan',
#  'itarema',
#  'obo',
#  'rognan',
#  'parelhas',
#  'marcona',
#  'gashua',
#  'channel-port aux basques',
#  'puerto leguizamo',
#  'victoria',
#  'oktyabrskiy',
#  'miri',
#  'lovozero',
#  'norrtalje',
#  'gambo',
#  'mayo',
#  'poronaysk',
#  'kungurtug',
#  'seymchan',
#  'lakki marwat',
#  'igarka',
#  'kadykchan',
#  'new ulm',
#  'krasnoyarsk-45',
#  'tura',
#  'ulverstone',
#  'muskegon',
#  'ndioum',
#  'the valley',
#  'necochea',
#  'bilma',
#  'clyde river',
#  'newcastle',
#  'khash',
#  'codajas',
#  'hay river',
#  'lubao',
#  'semnan',
#  'sale',
#  'santa catarina de tepehuanes',
#  'igra',
#  'kalvarija',
#  'midland',
#  'rehoboth',
#  'pipri',
#  'santa maria del oro',
#  'presidente olegario',
#  'lata',
#  'mumford',
#  'biak',
#  'camacha',
#  'suntar',
#  'akdepe',
#  'cabinda',
#  'erdokertes',
#  'ambunti',
#  'gidole',
#  'margate',
#  'san juan',
#  'christchurch',
#  'humberto de campos',
#  'kaduqli',
#  'rockland',
#  'atikokan',
#  'falun',
#  'lensk',
#  'dudinka',
#  'cockburn town',
#  'kruisfontein',
#  'toktogul',
#  'okato',
#  'fort saint john',
#  'ambilobe',
#  'poya',
#  'raudeberg',
#  'hervey bay',
#  'omboue',
#  'aranda de duero',
#  'kalmunai',
#  'saint-junien',
#  'samusu',
#  'jiayuguan',
#  'comodoro rivadavia',
#  'henties bay',
#  'ngunguru',
#  'juneau',
#  'tupik',
#  'katol',
#  'padang',
#  'pangai',
#  'pudozh',
#  'rapid valley',
#  'hambantota',
#  'kostomuksha',
#  'leshukonskoye',
#  'san isidro',
#  'kongoussi',
#  'puerto escondido',
#  'aykhal',
#  'pamplona',
#  'malmyzh',
#  'manono',
#  'harsin',
#  'conde',
#  'mombetsu',
#  'aranos',
#  'sorong',
#  'jawhar',
#  'mareeba',
#  'jiexiu',
#  'gbarnga',
#  'saint-pierre',
#  'sonoita',
#  'oga',
#  'saint-leu',
#  'brigantine',
#  'yulara',
#  'ardistan',
#  'setermoen',
#  'pemberton',
#  'tutoia',
#  'olmos',
#  'puri',
#  'aksehir',
#  'ozu',
#  'kang',
#  'gariaband',
#  'san andres del rabanedo',
#  'vaitape',
#  'santa vitoria',
#  'la asuncion',
#  'umm bab',
#  'sataua',
#  'santo tomas',
#  'akot',
#  'kamenka',
#  'morgan city',
#  'altona',
#  'nortelandia',
#  'tsabong',
#  'mentok',
#  'kabale',
#  'lundazi',
#  'iqaluit',
#  'kunstat',
#  'mundo nuevo',
#  'muravlenko',
#  'puteyets',
#  'lander',
#  'maxixe',
#  'ladario',
#  'corumba',
#  'tilichiki',
#  'caravelas',
#  'mnogovershinnyy',
#  'salobrena',
#  'bloomington',
#  'xuddur',
#  'okha',
#  'zhengjiatun',
#  'dunayivtsi',
#  'zhicheng',
#  'wuning',
#  'saryozek',
#  'wattegama',
#  'port hedland',
#  'tha muang',
#  'vila franca do campo',
#  'bilecik',
#  'phan rang',
#  'okhotsk',
#  'mbamba',
#  'josanicka banja',
#  'sobolevo',
#  'ormara',
#  'karpathos',
#  'geraldton',
#  'hihifo',
#  'barbacena',
#  'tulsipur',
#  'pizarro',
#  'huarmey',
#  'eenhana',
#  'robertsport',
#  'ushtobe',
#  'ondangwa',
#  'san lorenzo de el escorial',
#  'merauke',
#  'denpasar',
#  'babanusah',
#  'areosa',
#  'bundaberg',
#  'kieta',
#  'maulvi bazar',
#  'qaqortoq',
#  'lindi',
#  'jalu',
#  'san luis',
#  'miracema do tocantins',
#  'sawtell',
#  'tateyama',
#  'lahad datu',
#  'siilinjarvi',
#  'harkany',
#  'vestmannaeyjar',
#  'rock springs',
#  'zavallya',
#  'lock haven',
#  'zirandaro',
#  'dryden',
#  'qabis',
#  'jiuquan',
#  'bereda',
#  'katsina',
#  'boueni',
#  'grand junction',
#  'almaznyy',
#  'gangotri',
#  'lasa',
#  'hanzhong',
#  'newport',
#  'ati',
#  'manica',
#  'gondar',
#  'morwell',
#  'sirsa',
#  'corbita',
#  'dingle',
#  'menongue',
#  'kamenskoye',
#  'valparaiso',
#  'andrews',
#  'serik',
#  'alberton',
#  'sakakah',
#  'buala',
#  'rundu',
#  'filingue',
#  'bhag',
#  'thunder bay',
#  'longhua',
#  'saint-francois',
#  'norsup',
#  'iquitos',
#  'nguiu',
#  'shimoda',
#  'taoudenni',
#  'foumban']

# %%
# Import the API key.
import sys
sys.path.append('../')
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(nearest_cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_descript=city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description":city_weather_descript,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 2 | atuona
# Processing Record 2 of Set 2 | barrow
# Processing Record 3 of Set 2 | qaanaaq
# Processing Record 4 of Set 2 | punta arenas
# Processing Record 5 of Set 2 | liwale
# Processing Record 6 of Set 2 | hamilton
# Processing Record 7 of Set 2 | east london
# Processing Record 8 of Set 2 | mar del plata
# Processing Record 9 of Set 2 | nyaunglebin
# Processing Record 10 of Set 2 | jamestown
# Processing Record 11 of Set 2 | oranjemund
# Processing Record 12 of Set 2 | busselton
# Processing Record 13 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 2 | roald
# Processing Record 15 of Set 2 | moerai
# Processing Record 16 of Set 2 | san quintin
# Processing Record 17 of Set 2 | butaritari
# Processing Record 18 of Set 2 | hastings
# Processing Record 19 of Set 2 | aksarka
# Processing Record 20 of Set 2 | komsomolskiy
# Processing Record 21 of Set 2 | mataura
# Processing Record 22 of Set 2 | vaini
# Processing Record 23 of Set 2 | broome
# Processing Record 24 of Set 2 | avarua
# Processing Record 25 of Set 2 | severo-kurilsk
# Processing Record 26 of Set 2 | koosa
# Processing Record 27 of Set 2 | killybegs
# Processing Record 28 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 2 | vila velha
# Processing Record 30 of Set 2 | hithadhoo
# Processing Record 31 of Set 2 | arraial do cabo
# Processing Record 32 of Set 2 | harer
# Processing Record 33 of Set 2 | narsaq
# Processing Record 34 of Set 2 | kapaa
# Processing Record 35 of Set 2 | ushuaia
# Processing Record 36 of Set 2 | hermanus
# Processing Record 37 of Set 2 | camana
# Processing Record 38 of Set 2 | leh
# Processing Record 39 of Set 2 | thanh hoa
# Processing Record 40 of Set 2 | port alfred
# Processing Record 41 of Set 2 | mount isa
# Processing Record 42 of Set 2 | ostrovnoy
# Processing Record 43 of Set 2 | hobart
# Processing Record 44 of Set 2 | xichang
# Processing Record 45 of Set 2 | mandalgovi
# Processing Record 46 of Set 2 | new norfolk
# Processing Record 47 of Set 2 | namibe
# Processing Record 48 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 49 of Set 2 | ketchikan
# Processing Record 50 of Set 2 | mangrol
# Processing Record 1 of Set 3 | alofi
# Processing Record 2 of Set 3 | yellowknife
# Processing Record 3 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 4 of Set 3 | keti bandar
# Processing Record 5 of Set 3 | nikolskoye
# Processing Record 6 of Set 3 | lansdale
# Processing Record 7 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 3 | aksha
# Processing Record 9 of Set 3 | sur
# Processing Record 10 of Set 3 | steamboat springs
# Processing Record 11 of Set 3 | hami
# Processing Record 12 of Set 3 | dezful
# Processing Record 13 of Set 3 | sawakin
# Processing Record 14 of Set 3 | albany
# Processing Record 15 of Set 3 | vardo
# Processing Record 16 of Set 3 | sola
# Processing Record 17 of Set 3 | hualmay
# Processing Record 18 of Set 3 | hilo
# Processing Record 19 of Set 3 | plettenberg bay
# Processing Record 20 of Set 3 | kon tum
# Processing Record 21 of Set 3 | minab
# Processing Record 22 of Set 3 | rikitea
# Processing Record 23 of Set 3 | manggar
# Processing Record 24 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 25 of Set 3 | antofagasta
# Processing Record 26 of Set 3 | cidreira
# Processing Record 27 of Set 3 | khotyn
# Processing Record 28 of Set 3 | ust-kulom
# Processing Record 29 of Set 3 | hovd
# Processing Record 30 of Set 3 | provideniya
# Processing Record 31 of Set 3 | yerbogachen
# Processing Record 32 of Set 3 | port elizabeth
# Processing Record 33 of Set 3 | kyzyl-mazhalyk
# Processing Record 34 of Set 3 | udachnyy
# Processing Record 35 of Set 3 | sherlovaya gora
# Processing Record 36 of Set 3 | khatanga
# Processing Record 37 of Set 3 | aklavik
# Processing Record 38 of Set 3 | lethem
# Processing Record 39 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 3 | bonthe
# Processing Record 41 of Set 3 | norman wells
# Processing Record 42 of Set 3 | chokurdakh
# Processing Record 43 of Set 3 | xiaoweizhai
# Processing Record 44 of Set 3 | cabo san lucas
# Processing Record 45 of Set 3 | coquimbo
# Processing Record 46 of Set 3 | gorontalo
# Processing Record 47 of Set 3 | suao
# City not found. Skipping...
# Processing Record 48 of Set 3 | asfi
# Processing Record 49 of Set 3 | chicama
# Processing Record 50 of Set 3 | grand gaube
# Processing Record 1 of Set 4 | ancud
# Processing Record 2 of Set 4 | mapiri
# Processing Record 3 of Set 4 | sitka
# Processing Record 4 of Set 4 | bacuit
# City not found. Skipping...
# Processing Record 5 of Set 4 | bluff
# Processing Record 6 of Set 4 | cape town
# Processing Record 7 of Set 4 | rincon
# Processing Record 8 of Set 4 | iquique
# Processing Record 9 of Set 4 | illapel
# Processing Record 10 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 4 | karratha
# Processing Record 12 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 4 | port lincoln
# Processing Record 14 of Set 4 | coihaique
# Processing Record 15 of Set 4 | georgetown
# Processing Record 16 of Set 4 | sakaiminato
# Processing Record 17 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 4 | harper
# Processing Record 20 of Set 4 | portland
# Processing Record 21 of Set 4 | awallan
# Processing Record 22 of Set 4 | batagay-alyta
# Processing Record 23 of Set 4 | katherine
# Processing Record 24 of Set 4 | kolyvan
# Processing Record 25 of Set 4 | lenger
# Processing Record 26 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 4 | fortuna
# Processing Record 28 of Set 4 | esperance
# Processing Record 29 of Set 4 | mizdah
# Processing Record 30 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 4 | carnarvon
# Processing Record 32 of Set 4 | wynyard
# Processing Record 33 of Set 4 | mount gambier
# Processing Record 34 of Set 4 | puerto ayora
# Processing Record 35 of Set 4 | port keats
# Processing Record 36 of Set 4 | luderitz
# Processing Record 37 of Set 4 | san vicente
# Processing Record 38 of Set 4 | rawson
# Processing Record 39 of Set 4 | kaitangata
# Processing Record 40 of Set 4 | kamra
# Processing Record 41 of Set 4 | piacabucu
# Processing Record 42 of Set 4 | abu zabad
# Processing Record 43 of Set 4 | port-gentil
# Processing Record 44 of Set 4 | saldanha
# Processing Record 45 of Set 4 | bontang
# Processing Record 46 of Set 4 | rio grande
# Processing Record 47 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 4 | isla mujeres
# Processing Record 49 of Set 4 | north bend
# Processing Record 50 of Set 4 | ilulissat
# Processing Record 1 of Set 5 | klaksvik
# Processing Record 2 of Set 5 | inverell
# Processing Record 3 of Set 5 | nanhai
# Processing Record 4 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 5 | pirovskoye
# Processing Record 6 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 5 | riyadh
# Processing Record 8 of Set 5 | lebu
# Processing Record 9 of Set 5 | luanda
# Processing Record 10 of Set 5 | deshnok
# Processing Record 11 of Set 5 | bambous virieux
# Processing Record 12 of Set 5 | bayir
# Processing Record 13 of Set 5 | morondava
# Processing Record 14 of Set 5 | namatanai
# Processing Record 15 of Set 5 | henderson
# Processing Record 16 of Set 5 | faya
# Processing Record 17 of Set 5 | sinnamary
# Processing Record 18 of Set 5 | koungou
# Processing Record 19 of Set 5 | kibaya
# Processing Record 20 of Set 5 | batticaloa
# Processing Record 21 of Set 5 | westlock
# Processing Record 22 of Set 5 | nemuro
# Processing Record 23 of Set 5 | hasaki
# Processing Record 24 of Set 5 | castro
# Processing Record 25 of Set 5 | atar
# Processing Record 26 of Set 5 | kirakira
# Processing Record 27 of Set 5 | marzuq
# Processing Record 28 of Set 5 | narasannapeta
# Processing Record 29 of Set 5 | inta
# Processing Record 30 of Set 5 | saskylakh
# Processing Record 31 of Set 5 | syumsi
# Processing Record 32 of Set 5 | bambanglipuro
# Processing Record 33 of Set 5 | inhambane
# Processing Record 34 of Set 5 | tasiilaq
# Processing Record 35 of Set 5 | haines junction
# Processing Record 36 of Set 5 | lavrentiya
# Processing Record 37 of Set 5 | codrington
# Processing Record 38 of Set 5 | cascais
# Processing Record 39 of Set 5 | anadyr
# Processing Record 40 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 41 of Set 5 | airai
# Processing Record 42 of Set 5 | nome
# Processing Record 43 of Set 5 | kavaratti
# Processing Record 44 of Set 5 | faanui
# Processing Record 45 of Set 5 | kviteseid
# Processing Record 46 of Set 5 | arkhangelos
# City not found. Skipping...
# Processing Record 47 of Set 5 | prince rupert
# Processing Record 48 of Set 5 | tiksi
# Processing Record 49 of Set 5 | bombay
# Processing Record 50 of Set 5 | lumeje
# Processing Record 1 of Set 6 | fomboni
# Processing Record 2 of Set 6 | tezu
# Processing Record 3 of Set 6 | kodiak
# Processing Record 4 of Set 6 | odlabari
# Processing Record 5 of Set 6 | bonavista
# Processing Record 6 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 6 | nushki
# Processing Record 8 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 9 of Set 6 | santiago
# Processing Record 10 of Set 6 | katsuura
# Processing Record 11 of Set 6 | ampanihy
# Processing Record 12 of Set 6 | macaboboni
# City not found. Skipping...
# Processing Record 13 of Set 6 | cumaribo
# City not found. Skipping...
# Processing Record 14 of Set 6 | port hardy
# Processing Record 15 of Set 6 | bredasdorp
# Processing Record 16 of Set 6 | nanortalik
# Processing Record 17 of Set 6 | ust-tsilma
# Processing Record 18 of Set 6 | jacqueville
# Processing Record 19 of Set 6 | kalmar
# Processing Record 20 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 21 of Set 6 | siocon
# Processing Record 22 of Set 6 | upernavik
# Processing Record 23 of Set 6 | meadow lake
# Processing Record 24 of Set 6 | dandong
# Processing Record 25 of Set 6 | taksimo
# Processing Record 26 of Set 6 | gornopravdinsk
# Processing Record 27 of Set 6 | byron bay
# Processing Record 28 of Set 6 | port-de-paix
# City not found. Skipping...
# Processing Record 29 of Set 6 | dikson
# Processing Record 30 of Set 6 | honiara
# Processing Record 31 of Set 6 | torbay
# Processing Record 32 of Set 6 | saint-philippe
# Processing Record 33 of Set 6 | tigil
# Processing Record 34 of Set 6 | emerald
# Processing Record 35 of Set 6 | bosaso
# Processing Record 36 of Set 6 | baruun-urt
# Processing Record 37 of Set 6 | sao filipe
# Processing Record 38 of Set 6 | simao
# Processing Record 39 of Set 6 | ciras
# City not found. Skipping...
# Processing Record 40 of Set 6 | pacifica
# Processing Record 41 of Set 6 | cherskiy
# Processing Record 42 of Set 6 | kupang
# Processing Record 43 of Set 6 | salalah
# Processing Record 44 of Set 6 | nouadhibou
# Processing Record 45 of Set 6 | sinegorye
# Processing Record 46 of Set 6 | kharhial
# Processing Record 47 of Set 6 | dauriya
# Processing Record 48 of Set 6 | chuy
# Processing Record 49 of Set 6 | charters towers
# Processing Record 50 of Set 6 | kavieng
# Processing Record 1 of Set 7 | santa cruz
# Processing Record 2 of Set 7 | ayagoz
# Processing Record 3 of Set 7 | corinto
# Processing Record 4 of Set 7 | poum
# Processing Record 5 of Set 7 | ober-ramstadt
# Processing Record 6 of Set 7 | te anau
# Processing Record 7 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 7 | kikwit
# Processing Record 9 of Set 7 | mehamn
# Processing Record 10 of Set 7 | port moresby
# Processing Record 11 of Set 7 | fukue
# Processing Record 12 of Set 7 | diamantino
# Processing Record 13 of Set 7 | longyearbyen
# Processing Record 14 of Set 7 | saint pete beach
# Processing Record 15 of Set 7 | presidencia roque saenz pena
# Processing Record 16 of Set 7 | isangel
# Processing Record 17 of Set 7 | dunedin
# Processing Record 18 of Set 7 | masuda
# Processing Record 19 of Set 7 | alcains
# Processing Record 20 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 7 | waddan
# Processing Record 22 of Set 7 | albanel
# Processing Record 23 of Set 7 | micheweni
# Processing Record 24 of Set 7 | bardiyah
# Processing Record 25 of Set 7 | obluche
# City not found. Skipping...
# Processing Record 26 of Set 7 | santa isabel do rio negro
# Processing Record 27 of Set 7 | ponta do sol
# Processing Record 28 of Set 7 | tuktoyaktuk
# Processing Record 29 of Set 7 | bengkulu
# Processing Record 30 of Set 7 | axim
# Processing Record 31 of Set 7 | richards bay
# Processing Record 32 of Set 7 | roma
# Processing Record 33 of Set 7 | kargasok
# Processing Record 34 of Set 7 | jijiga
# Processing Record 35 of Set 7 | hendijan
# City not found. Skipping...
# Processing Record 36 of Set 7 | leningradskiy
# Processing Record 37 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 38 of Set 7 | gat
# Processing Record 39 of Set 7 | pahrump
# Processing Record 40 of Set 7 | fairmont
# Processing Record 41 of Set 7 | palmer
# Processing Record 42 of Set 7 | mahebourg
# Processing Record 43 of Set 7 | san cristobal
# Processing Record 44 of Set 7 | siuna
# Processing Record 45 of Set 7 | marawi
# Processing Record 46 of Set 7 | limbang
# Processing Record 47 of Set 7 | fosforitnyy
# Processing Record 48 of Set 7 | bridgetown
# Processing Record 49 of Set 7 | pangnirtung
# Processing Record 50 of Set 7 | medea
# Processing Record 1 of Set 8 | samana
# Processing Record 2 of Set 8 | dongning
# Processing Record 3 of Set 8 | bowen
# Processing Record 4 of Set 8 | mednogorsk
# Processing Record 5 of Set 8 | praia da vitoria
# Processing Record 6 of Set 8 | mao
# Processing Record 7 of Set 8 | ribeira grande
# Processing Record 8 of Set 8 | elko
# Processing Record 9 of Set 8 | marrakesh
# Processing Record 10 of Set 8 | karaton
# Processing Record 11 of Set 8 | ejido
# Processing Record 12 of Set 8 | half moon bay
# Processing Record 13 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 14 of Set 8 | macherla
# Processing Record 15 of Set 8 | usinsk
# Processing Record 16 of Set 8 | kargil
# Processing Record 17 of Set 8 | russell
# Processing Record 18 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 8 | lengshuitan
# Processing Record 20 of Set 8 | safita
# Processing Record 21 of Set 8 | san patricio
# Processing Record 22 of Set 8 | winnemucca
# Processing Record 23 of Set 8 | dubbo
# Processing Record 24 of Set 8 | husavik
# Processing Record 25 of Set 8 | bogovarovo
# Processing Record 26 of Set 8 | tuatapere
# Processing Record 27 of Set 8 | verkhoyansk
# Processing Record 28 of Set 8 | pokosnoye
# Processing Record 29 of Set 8 | alcantara
# Processing Record 30 of Set 8 | formiga
# Processing Record 31 of Set 8 | teya
# Processing Record 32 of Set 8 | huoqiu
# Processing Record 33 of Set 8 | kollam
# Processing Record 34 of Set 8 | berlevag
# Processing Record 35 of Set 8 | pisco
# Processing Record 36 of Set 8 | raga
# Processing Record 37 of Set 8 | ulaangom
# Processing Record 38 of Set 8 | garissa
# Processing Record 39 of Set 8 | rondonopolis
# Processing Record 40 of Set 8 | challapata
# Processing Record 41 of Set 8 | uk
# City not found. Skipping...
# Processing Record 42 of Set 8 | fare
# Processing Record 43 of Set 8 | guangyuan
# Processing Record 44 of Set 8 | xinyang
# Processing Record 45 of Set 8 | smithers
# Processing Record 46 of Set 8 | mecca
# Processing Record 47 of Set 8 | thompson
# Processing Record 48 of Set 8 | waingapu
# Processing Record 49 of Set 8 | kununurra
# Processing Record 50 of Set 8 | krasnorechenskiy
# Processing Record 1 of Set 9 | granadilla de abona
# Processing Record 2 of Set 9 | port blair
# Processing Record 3 of Set 9 | saint george
# Processing Record 4 of Set 9 | bandarbeyla
# Processing Record 5 of Set 9 | grand-lahou
# Processing Record 6 of Set 9 | avera
# Processing Record 7 of Set 9 | mahaicony
# City not found. Skipping...
# Processing Record 8 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 9 of Set 9 | pevek
# Processing Record 10 of Set 9 | skibbereen
# Processing Record 11 of Set 9 | qingdao
# Processing Record 12 of Set 9 | macapa
# Processing Record 13 of Set 9 | cayenne
# Processing Record 14 of Set 9 | chitungwiza
# Processing Record 15 of Set 9 | ugoofaaru
# Processing Record 16 of Set 9 | butembo
# Processing Record 17 of Set 9 | kiama
# Processing Record 18 of Set 9 | ambam
# Processing Record 19 of Set 9 | srandakan
# Processing Record 20 of Set 9 | mayumba
# Processing Record 21 of Set 9 | deputatskiy
# Processing Record 22 of Set 9 | atakpame
# Processing Record 23 of Set 9 | najran
# Processing Record 24 of Set 9 | mildura
# Processing Record 25 of Set 9 | xinzhi
# Processing Record 26 of Set 9 | cam pha
# City not found. Skipping...
# Processing Record 27 of Set 9 | zlotoryja
# Processing Record 28 of Set 9 | banmo
# City not found. Skipping...
# Processing Record 29 of Set 9 | nouakchott
# Processing Record 30 of Set 9 | moyale
# Processing Record 31 of Set 9 | sao joao da barra
# Processing Record 32 of Set 9 | eydhafushi
# Processing Record 33 of Set 9 | semey
# Processing Record 34 of Set 9 | san andres
# Processing Record 35 of Set 9 | marv dasht
# City not found. Skipping...
# Processing Record 36 of Set 9 | parana
# Processing Record 37 of Set 9 | saquena
# Processing Record 38 of Set 9 | brodick
# Processing Record 39 of Set 9 | eureka
# Processing Record 40 of Set 9 | mogochin
# City not found. Skipping...
# Processing Record 41 of Set 9 | vanavara
# Processing Record 42 of Set 9 | bilibino
# Processing Record 43 of Set 9 | farmington
# Processing Record 44 of Set 9 | belaya gora
# Processing Record 45 of Set 9 | port macquarie
# Processing Record 46 of Set 9 | andevoranto
# City not found. Skipping...
# Processing Record 47 of Set 9 | hofn
# Processing Record 48 of Set 9 | ankara
# Processing Record 49 of Set 9 | lompoc
# Processing Record 50 of Set 9 | meulaboh
# Processing Record 1 of Set 10 | maragogi
# Processing Record 2 of Set 10 | gubkinskiy
# Processing Record 3 of Set 10 | puerto madryn
# Processing Record 4 of Set 10 | saint-denis
# Processing Record 5 of Set 10 | kuusamo
# Processing Record 6 of Set 10 | gimli
# Processing Record 7 of Set 10 | izumo
# Processing Record 8 of Set 10 | itoman
# Processing Record 9 of Set 10 | kenai
# Processing Record 10 of Set 10 | fairbanks
# Processing Record 11 of Set 10 | oytal
# Processing Record 12 of Set 10 | tallahassee
# Processing Record 13 of Set 10 | whitianga
# Processing Record 14 of Set 10 | barentu
# Processing Record 15 of Set 10 | cotonou
# Processing Record 16 of Set 10 | darlawn
# Processing Record 17 of Set 10 | constantine
# Processing Record 18 of Set 10 | brae
# Processing Record 19 of Set 10 | gorom-gorom
# Processing Record 20 of Set 10 | lynn haven
# Processing Record 21 of Set 10 | lazaro cardenas
# Processing Record 22 of Set 10 | fredericksburg
# Processing Record 23 of Set 10 | porvoo
# Processing Record 24 of Set 10 | nelson bay
# Processing Record 25 of Set 10 | cyangugu
# Processing Record 26 of Set 10 | blenheim
# Processing Record 27 of Set 10 | constitucion
# Processing Record 28 of Set 10 | vanderbijlpark
# Processing Record 29 of Set 10 | tumpat
# Processing Record 30 of Set 10 | saint-paul
# Processing Record 31 of Set 10 | kahului
# Processing Record 32 of Set 10 | carepa
# Processing Record 33 of Set 10 | zbarazh
# Processing Record 34 of Set 10 | ahipara
# Processing Record 35 of Set 10 | presidente medici
# Processing Record 36 of Set 10 | thinadhoo
# Processing Record 37 of Set 10 | lumsden
# Processing Record 38 of Set 10 | magelang
# Processing Record 39 of Set 10 | mahibadhoo
# Processing Record 40 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 10 | kakonko
# Processing Record 42 of Set 10 | karamay
# City not found. Skipping...
# Processing Record 43 of Set 10 | olafsvik
# Processing Record 44 of Set 10 | peniche
# Processing Record 45 of Set 10 | tahe
# Processing Record 46 of Set 10 | kano
# Processing Record 47 of Set 10 | zyryanovsk
# Processing Record 48 of Set 10 | high level
# Processing Record 49 of Set 10 | naze
# Processing Record 50 of Set 10 | talnakh
# Processing Record 1 of Set 11 | gizo
# Processing Record 2 of Set 11 | kokopo
# Processing Record 3 of Set 11 | smidovich
# Processing Record 4 of Set 11 | college
# Processing Record 5 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 11 | watsa
# Processing Record 7 of Set 11 | zachagansk
# City not found. Skipping...
# Processing Record 8 of Set 11 | bathsheba
# Processing Record 9 of Set 11 | los llanos de aridane
# Processing Record 10 of Set 11 | dianopolis
# City not found. Skipping...
# Processing Record 11 of Set 11 | kearney
# Processing Record 12 of Set 11 | aripuana
# Processing Record 13 of Set 11 | wairoa
# Processing Record 14 of Set 11 | tabuk
# Processing Record 15 of Set 11 | fonte boa
# Processing Record 16 of Set 11 | souillac
# Processing Record 17 of Set 11 | vanimo
# Processing Record 18 of Set 11 | hauterive
# Processing Record 19 of Set 11 | jumla
# Processing Record 20 of Set 11 | san matias
# Processing Record 21 of Set 11 | ishigaki
# Processing Record 22 of Set 11 | xining
# Processing Record 23 of Set 11 | belmonte
# Processing Record 24 of Set 11 | stephenville
# Processing Record 25 of Set 11 | beringovskiy
# Processing Record 26 of Set 11 | phek
# Processing Record 27 of Set 11 | caborca
# Processing Record 28 of Set 11 | kloulklubed
# Processing Record 29 of Set 11 | leavenworth
# Processing Record 30 of Set 11 | chenghai
# Processing Record 31 of Set 11 | stornoway
# Processing Record 32 of Set 11 | bethel
# Processing Record 33 of Set 11 | moose factory
# Processing Record 34 of Set 11 | balezino
# Processing Record 35 of Set 11 | sampit
# Processing Record 36 of Set 11 | solsvik
# City not found. Skipping...
# Processing Record 37 of Set 11 | angoche
# Processing Record 38 of Set 11 | adrar
# Processing Record 39 of Set 11 | banjar
# Processing Record 40 of Set 11 | worthing
# Processing Record 41 of Set 11 | mugur-aksy
# Processing Record 42 of Set 11 | smirnykh
# Processing Record 43 of Set 11 | windhoek
# Processing Record 44 of Set 11 | olinda
# Processing Record 45 of Set 11 | tautira
# Processing Record 46 of Set 11 | dicabisagan
# Processing Record 47 of Set 11 | itarema
# Processing Record 48 of Set 11 | obo
# Processing Record 49 of Set 11 | rognan
# Processing Record 50 of Set 11 | parelhas
# Processing Record 1 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 12 | gashua
# Processing Record 3 of Set 12 | channel-port aux basques
# Processing Record 4 of Set 12 | puerto leguizamo
# Processing Record 5 of Set 12 | victoria
# Processing Record 6 of Set 12 | oktyabrskiy
# Processing Record 7 of Set 12 | miri
# Processing Record 8 of Set 12 | lovozero
# Processing Record 9 of Set 12 | norrtalje
# Processing Record 10 of Set 12 | gambo
# Processing Record 11 of Set 12 | mayo
# Processing Record 12 of Set 12 | poronaysk
# Processing Record 13 of Set 12 | kungurtug
# Processing Record 14 of Set 12 | seymchan
# Processing Record 15 of Set 12 | lakki marwat
# Processing Record 16 of Set 12 | igarka
# Processing Record 17 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 18 of Set 12 | new ulm
# Processing Record 19 of Set 12 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 20 of Set 12 | tura
# Processing Record 21 of Set 12 | ulverstone
# Processing Record 22 of Set 12 | muskegon
# Processing Record 23 of Set 12 | ndioum
# Processing Record 24 of Set 12 | the valley
# Processing Record 25 of Set 12 | necochea
# Processing Record 26 of Set 12 | bilma
# Processing Record 27 of Set 12 | clyde river
# Processing Record 28 of Set 12 | newcastle
# Processing Record 29 of Set 12 | khash
# Processing Record 30 of Set 12 | codajas
# Processing Record 31 of Set 12 | hay river
# Processing Record 32 of Set 12 | lubao
# Processing Record 33 of Set 12 | semnan
# Processing Record 34 of Set 12 | sale
# Processing Record 35 of Set 12 | santa catarina de tepehuanes
# Processing Record 36 of Set 12 | igra
# Processing Record 37 of Set 12 | kalvarija
# Processing Record 38 of Set 12 | midland
# Processing Record 39 of Set 12 | rehoboth
# Processing Record 40 of Set 12 | pipri
# Processing Record 41 of Set 12 | santa maria del oro
# Processing Record 42 of Set 12 | presidente olegario
# Processing Record 43 of Set 12 | lata
# Processing Record 44 of Set 12 | mumford
# Processing Record 45 of Set 12 | biak
# Processing Record 46 of Set 12 | camacha
# Processing Record 47 of Set 12 | suntar
# Processing Record 48 of Set 12 | akdepe
# Processing Record 49 of Set 12 | cabinda
# Processing Record 50 of Set 12 | erdokertes
# Processing Record 1 of Set 13 | ambunti
# Processing Record 2 of Set 13 | gidole
# Processing Record 3 of Set 13 | margate
# Processing Record 4 of Set 13 | san juan
# Processing Record 5 of Set 13 | christchurch
# Processing Record 6 of Set 13 | humberto de campos
# Processing Record 7 of Set 13 | kaduqli
# Processing Record 8 of Set 13 | rockland
# Processing Record 9 of Set 13 | atikokan
# Processing Record 10 of Set 13 | falun
# Processing Record 11 of Set 13 | lensk
# Processing Record 12 of Set 13 | dudinka
# Processing Record 13 of Set 13 | cockburn town
# Processing Record 14 of Set 13 | kruisfontein
# Processing Record 15 of Set 13 | toktogul
# Processing Record 16 of Set 13 | okato
# Processing Record 17 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 18 of Set 13 | ambilobe
# Processing Record 19 of Set 13 | poya
# Processing Record 20 of Set 13 | raudeberg
# Processing Record 21 of Set 13 | hervey bay
# Processing Record 22 of Set 13 | omboue
# Processing Record 23 of Set 13 | aranda de duero
# Processing Record 24 of Set 13 | kalmunai
# Processing Record 25 of Set 13 | saint-junien
# Processing Record 26 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 13 | jiayuguan
# Processing Record 28 of Set 13 | comodoro rivadavia
# Processing Record 29 of Set 13 | henties bay
# Processing Record 30 of Set 13 | ngunguru
# Processing Record 31 of Set 13 | juneau
# Processing Record 32 of Set 13 | tupik
# Processing Record 33 of Set 13 | katol
# Processing Record 34 of Set 13 | padang
# Processing Record 35 of Set 13 | pangai
# Processing Record 36 of Set 13 | pudozh
# Processing Record 37 of Set 13 | rapid valley
# Processing Record 38 of Set 13 | hambantota
# Processing Record 39 of Set 13 | kostomuksha
# Processing Record 40 of Set 13 | leshukonskoye
# Processing Record 41 of Set 13 | san isidro
# Processing Record 42 of Set 13 | kongoussi
# Processing Record 43 of Set 13 | puerto escondido
# Processing Record 44 of Set 13 | aykhal
# Processing Record 45 of Set 13 | pamplona
# Processing Record 46 of Set 13 | malmyzh
# Processing Record 47 of Set 13 | manono
# Processing Record 48 of Set 13 | harsin
# Processing Record 49 of Set 13 | conde
# Processing Record 50 of Set 13 | mombetsu
# Processing Record 1 of Set 14 | aranos
# Processing Record 2 of Set 14 | sorong
# Processing Record 3 of Set 14 | jawhar
# Processing Record 4 of Set 14 | mareeba
# Processing Record 5 of Set 14 | jiexiu
# Processing Record 6 of Set 14 | gbarnga
# Processing Record 7 of Set 14 | saint-pierre
# Processing Record 8 of Set 14 | sonoita
# Processing Record 9 of Set 14 | oga
# Processing Record 10 of Set 14 | saint-leu
# Processing Record 11 of Set 14 | brigantine
# Processing Record 12 of Set 14 | yulara
# Processing Record 13 of Set 14 | ardistan
# City not found. Skipping...
# Processing Record 14 of Set 14 | setermoen
# Processing Record 15 of Set 14 | pemberton
# Processing Record 16 of Set 14 | tutoia
# Processing Record 17 of Set 14 | olmos
# Processing Record 18 of Set 14 | puri
# Processing Record 19 of Set 14 | aksehir
# Processing Record 20 of Set 14 | ozu
# Processing Record 21 of Set 14 | kang
# Processing Record 22 of Set 14 | gariaband
# Processing Record 23 of Set 14 | san andres del rabanedo
# Processing Record 24 of Set 14 | vaitape
# Processing Record 25 of Set 14 | santa vitoria
# Processing Record 26 of Set 14 | la asuncion
# Processing Record 27 of Set 14 | umm bab
# Processing Record 28 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 29 of Set 14 | santo tomas
# Processing Record 30 of Set 14 | akot
# Processing Record 31 of Set 14 | kamenka
# Processing Record 32 of Set 14 | morgan city
# Processing Record 33 of Set 14 | altona
# Processing Record 34 of Set 14 | nortelandia
# Processing Record 35 of Set 14 | tsabong
# Processing Record 36 of Set 14 | mentok
# City not found. Skipping...
# Processing Record 37 of Set 14 | kabale
# Processing Record 38 of Set 14 | lundazi
# Processing Record 39 of Set 14 | iqaluit
# Processing Record 40 of Set 14 | kunstat
# Processing Record 41 of Set 14 | mundo nuevo
# Processing Record 42 of Set 14 | muravlenko
# Processing Record 43 of Set 14 | puteyets
# Processing Record 44 of Set 14 | lander
# Processing Record 45 of Set 14 | maxixe
# Processing Record 46 of Set 14 | ladario
# Processing Record 47 of Set 14 | corumba
# Processing Record 48 of Set 14 | tilichiki
# Processing Record 49 of Set 14 | caravelas
# Processing Record 50 of Set 14 | mnogovershinnyy
# Processing Record 1 of Set 15 | salobrena
# Processing Record 2 of Set 15 | bloomington
# Processing Record 3 of Set 15 | xuddur
# Processing Record 4 of Set 15 | okha
# Processing Record 5 of Set 15 | zhengjiatun
# Processing Record 6 of Set 15 | dunayivtsi
# City not found. Skipping...
# Processing Record 7 of Set 15 | zhicheng
# Processing Record 8 of Set 15 | wuning
# Processing Record 9 of Set 15 | saryozek
# Processing Record 10 of Set 15 | wattegama
# Processing Record 11 of Set 15 | port hedland
# Processing Record 12 of Set 15 | tha muang
# Processing Record 13 of Set 15 | vila franca do campo
# Processing Record 14 of Set 15 | bilecik
# Processing Record 15 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 16 of Set 15 | okhotsk
# Processing Record 17 of Set 15 | mbamba
# Processing Record 18 of Set 15 | josanicka banja
# Processing Record 19 of Set 15 | sobolevo
# Processing Record 20 of Set 15 | ormara
# Processing Record 21 of Set 15 | karpathos
# Processing Record 22 of Set 15 | geraldton
# Processing Record 23 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 24 of Set 15 | barbacena
# Processing Record 25 of Set 15 | tulsipur
# Processing Record 26 of Set 15 | pizarro
# Processing Record 27 of Set 15 | huarmey
# Processing Record 28 of Set 15 | eenhana
# Processing Record 29 of Set 15 | robertsport
# Processing Record 30 of Set 15 | ushtobe
# Processing Record 31 of Set 15 | ondangwa
# Processing Record 32 of Set 15 | san lorenzo de el escorial
# Processing Record 33 of Set 15 | merauke
# Processing Record 34 of Set 15 | denpasar
# Processing Record 35 of Set 15 | babanusah
# City not found. Skipping...
# Processing Record 36 of Set 15 | areosa
# Processing Record 37 of Set 15 | bundaberg
# Processing Record 38 of Set 15 | kieta
# Processing Record 39 of Set 15 | maulvi bazar
# City not found. Skipping...
# Processing Record 40 of Set 15 | qaqortoq
# Processing Record 41 of Set 15 | lindi
# Processing Record 42 of Set 15 | jalu
# Processing Record 43 of Set 15 | san luis
# Processing Record 44 of Set 15 | miracema do tocantins
# Processing Record 45 of Set 15 | sawtell
# Processing Record 46 of Set 15 | tateyama
# Processing Record 47 of Set 15 | lahad datu
# Processing Record 48 of Set 15 | siilinjarvi
# Processing Record 49 of Set 15 | harkany
# Processing Record 50 of Set 15 | vestmannaeyjar
# Processing Record 1 of Set 16 | rock springs
# Processing Record 2 of Set 16 | zavallya
# Processing Record 3 of Set 16 | lock haven
# Processing Record 4 of Set 16 | zirandaro
# Processing Record 5 of Set 16 | dryden
# Processing Record 6 of Set 16 | qabis
# City not found. Skipping...
# Processing Record 7 of Set 16 | jiuquan
# Processing Record 8 of Set 16 | bereda
# Processing Record 9 of Set 16 | katsina
# Processing Record 10 of Set 16 | boueni
# Processing Record 11 of Set 16 | grand junction
# Processing Record 12 of Set 16 | almaznyy
# Processing Record 13 of Set 16 | gangotri
# City not found. Skipping...
# Processing Record 14 of Set 16 | lasa
# Processing Record 15 of Set 16 | hanzhong
# Processing Record 16 of Set 16 | newport
# Processing Record 17 of Set 16 | ati
# Processing Record 18 of Set 16 | manica
# Processing Record 19 of Set 16 | gondar
# Processing Record 20 of Set 16 | morwell
# Processing Record 21 of Set 16 | sirsa
# Processing Record 22 of Set 16 | corbita
# Processing Record 23 of Set 16 | dingle
# Processing Record 24 of Set 16 | menongue
# Processing Record 25 of Set 16 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 16 | valparaiso
# Processing Record 27 of Set 16 | andrews
# Processing Record 28 of Set 16 | serik
# Processing Record 29 of Set 16 | alberton
# Processing Record 30 of Set 16 | sakakah
# Processing Record 31 of Set 16 | buala
# Processing Record 32 of Set 16 | rundu
# Processing Record 33 of Set 16 | filingue
# Processing Record 34 of Set 16 | bhag
# Processing Record 35 of Set 16 | thunder bay
# Processing Record 36 of Set 16 | longhua
# Processing Record 37 of Set 16 | saint-francois
# Processing Record 38 of Set 16 | norsup
# Processing Record 39 of Set 16 | iquitos
# Processing Record 40 of Set 16 | nguiu
# City not found. Skipping...
# Processing Record 41 of Set 16 | shimoda
# Processing Record 42 of Set 16 | taoudenni
# Processing Record 43 of Set 16 | foumban
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 726

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
df = pd.DataFrame(city_data)
df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Atuona  -9.8000 -139.0333     78.57        78          21
# 1         Barrow  71.2906 -156.7887     -0.38        78           0
# 2        Qaanaaq  77.4840  -69.3632      1.81        56          44
# 3   Punta Arenas -53.1500  -70.9167     55.51        58          40
# 4         Liwale  -9.7667   37.9333     69.37        99          99
# 5       Hamilton  39.1834  -84.5333     32.23        75         100
# 6    East London -33.0153   27.9116     72.21        73          70
# 7  Mar Del Plata -38.0023  -57.5575     82.42        62           0
# 8    Nyaunglebin  17.9500   96.7333     64.69        35           2
# 9      Jamestown  42.0970  -79.2353     21.29        65         100
#
#    Wind Speed Weather Description Country                 Date
# 0       20.29          light rain      PF  2022-02-25 21:29:24
# 1       28.77                snow      US  2022-02-25 21:30:22
# 2        8.10    scattered clouds      GL  2022-02-25 21:30:22
# 3       19.57    scattered clouds      CL  2022-02-25 21:30:23
# 4        1.83       moderate rain      TZ  2022-02-25 21:30:23
# 5       10.36     overcast clouds      US  2022-02-25 21:29:07
# 6       10.27       broken clouds      ZA  2022-02-25 21:30:24
# 7       13.80           clear sky      AR  2022-02-25 21:25:34
# 8        4.36           clear sky      MM  2022-02-25 21:30:25
# 9       14.97                mist      US  2022-02-25 21:28:57

# %%
# Drop Date column
drop_df=df.drop(['Date'], axis=1)
drop_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Atuona  -9.8000 -139.0333     78.57        78          21
# 1        Barrow  71.2906 -156.7887     -0.38        78           0
# 2       Qaanaaq  77.4840  -69.3632      1.81        56          44
# 3  Punta Arenas -53.1500  -70.9167     55.51        58          40
# 4        Liwale  -9.7667   37.9333     69.37        99          99
#
#    Wind Speed Weather Description Country
# 0       20.29          light rain      PF
# 1       28.77                snow      US
# 2        8.10    scattered clouds      GL
# 3       19.57    scattered clouds      CL
# 4        1.83       moderate rain      TZ

# %%
# Rename column
rename_df=drop_df.rename(columns={"Weather Description": "Current Weather"})
rename_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Atuona  -9.8000 -139.0333     78.57        78          21
# 1        Barrow  71.2906 -156.7887     -0.38        78           0
# 2       Qaanaaq  77.4840  -69.3632      1.81        56          44
# 3  Punta Arenas -53.1500  -70.9167     55.51        58          40
# 4        Liwale  -9.7667   37.9333     69.37        99          99
#
#    Wind Speed   Current Weather Country
# 0       20.29        light rain      PF
# 1       28.77              snow      US
# 2        8.10  scattered clouds      GL
# 3       19.57  scattered clouds      CL
# 4        1.83     moderate rain      TZ

# %%
# Reorder columns
city_data_df = rename_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Weather"]]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Atuona      PF  -9.8000 -139.0333     78.57        78          21
# 1         Barrow      US  71.2906 -156.7887     -0.38        78           0
# 2        Qaanaaq      GL  77.4840  -69.3632      1.81        56          44
# 3   Punta Arenas      CL -53.1500  -70.9167     55.51        58          40
# 4         Liwale      TZ  -9.7667   37.9333     69.37        99          99
# 5       Hamilton      US  39.1834  -84.5333     32.23        75         100
# 6    East London      ZA -33.0153   27.9116     72.21        73          70
# 7  Mar Del Plata      AR -38.0023  -57.5575     82.42        62           0
# 8    Nyaunglebin      MM  17.9500   96.7333     64.69        35           2
# 9      Jamestown      US  42.0970  -79.2353     21.29        65         100
#
#    Wind Speed   Current Weather
# 0       20.29        light rain
# 1       28.77              snow
# 2        8.10  scattered clouds
# 3       19.57  scattered clouds
# 4        1.83     moderate rain
# 5       10.36   overcast clouds
# 6       10.27     broken clouds
# 7       13.80         clear sky
# 8        4.36         clear sky
# 9       14.97              mist

# %%
# Create the output file (CSV).
output_data_file = "weatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
