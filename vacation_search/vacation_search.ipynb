# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
import sys
sys.path.append('../')
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../weather_database/weatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID          City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0        Atuona      PF  -9.8000 -139.0333     78.57        78
# 1        1        Barrow      US  71.2906 -156.7887     -0.38        78
# 2        2       Qaanaaq      GL  77.4840  -69.3632      1.81        56
# 3        3  Punta Arenas      CL -53.1500  -70.9167     55.51        58
# 4        4        Liwale      TZ  -9.7667   37.9333     69.37        99
#
#    Cloudiness  Wind Speed   Current Weather
# 0          21       20.29        light rain
# 1           0       28.77              snow
# 2          44        8.10  scattered clouds
# 3          40       19.57  scattered clouds
# 4          99        1.83     moderate rain

# %%
# Set index
city_data_df=city_data_df.set_index('City_ID')
city_data_df.head()
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0              Atuona      PF  -9.8000 -139.0333     78.57        78
# 1              Barrow      US  71.2906 -156.7887     -0.38        78
# 2             Qaanaaq      GL  77.4840  -69.3632      1.81        56
# 3        Punta Arenas      CL -53.1500  -70.9167     55.51        58
# 4              Liwale      TZ  -9.7667   37.9333     69.37        99
#
#          Cloudiness  Wind Speed   Current Weather
# City_ID
# 0                21       20.29        light rain
# 1                 0       28.77              snow
# 2                44        8.10  scattered clouds
# 3                40       19.57  scattered clouds
# 4                99        1.83     moderate rain

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 65
# What is the maximum temperature you would like for your trip? 85

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
# preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
#                                        (city_data_df["Max Temp"] >= min_temp)]
# preferred_cities_df.tail(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 707          Dingle      PH  10.9995  122.6711     73.35        91
# 709      Valparaiso      CL -33.0393  -71.6273     80.83        46
# 714           Buala      SB  -8.1450  159.5921     83.07        79
# 715           Rundu     NaN -17.9333   19.7667     74.05        52
# 716        Filingue      NE  14.3521    3.3168     75.36         8
# 717            Bhag      PK  29.0415   67.8239     70.03        19
# 721          Norsup      VU -16.0667  167.3833     81.50        79
# 722         Iquitos      PE  -3.7481  -73.2472     78.84        89
# 724       Taoudenni      ML  22.6783   -3.9836     84.20        10
# 725         Foumban      CM   5.7291   10.9001     69.44        22
#
#          Cloudiness  Wind Speed  Current Weather
# City_ID
# 707              87        8.77  overcast clouds
# 709               0       13.80        clear sky
# 714             100        8.21       light rain
# ...

# %%
# 4a. Determine if there are any empty rows.
city_data_df.count()
# Out:
# City               726
# Country            716
# Lat                726
# Lng                726
# Max Temp           726
# Humidity           726
# Cloudiness         726
# Wind Speed         726
# Current Weather    726
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
## DISCOVERED PANDAS INTERPRETING NA (NAMIMBIA) FOR NAN, REPLACING INSTEAD
corrected_city_data_df=city_data_df.fillna(value="Namimbia")
corrected_city_data_df.head(15)
# Out:
#                   City   Country      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0               Atuona        PF  -9.8000 -139.0333     78.57        78
# 1               Barrow        US  71.2906 -156.7887     -0.38        78
# 2              Qaanaaq        GL  77.4840  -69.3632      1.81        56
# 3         Punta Arenas        CL -53.1500  -70.9167     55.51        58
# 4               Liwale        TZ  -9.7667   37.9333     69.37        99
# 5             Hamilton        US  39.1834  -84.5333     32.23        75
# 6          East London        ZA -33.0153   27.9116     72.21        73
# 7        Mar Del Plata        AR -38.0023  -57.5575     82.42        62
# 8          Nyaunglebin        MM  17.9500   96.7333     64.69        35
# 9            Jamestown        US  42.0970  -79.2353     21.29        65
# 10          Oranjemund  Namimbia -28.5500   16.4333     65.37        90
# 11           Busselton        AU -33.6500  115.3333     66.09        77
# ...

# %%
# Determine if there are any empty rows.
corrected_city_data_df.count()
# Out:
# City               726
# Country            726
# Lat                726
# Lng                726
# Max Temp           726
# Humidity           726
# Cloudiness         726
# Wind Speed         726
# Current Weather    726
# dtype: int64

# %%
# CORRECTED 3. Filter the corrected_city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = corrected_city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (corrected_city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.tail(10)
# Out:
#                City   Country      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 707          Dingle        PH  10.9995  122.6711     73.35        91
# 709      Valparaiso        CL -33.0393  -71.6273     80.83        46
# 714           Buala        SB  -8.1450  159.5921     83.07        79
# 715           Rundu  Namimbia -17.9333   19.7667     74.05        52
# 716        Filingue        NE  14.3521    3.3168     75.36         8
# 717            Bhag        PK  29.0415   67.8239     70.03        19
# 721          Norsup        VU -16.0667  167.3833     81.50        79
# 722         Iquitos        PE  -3.7481  -73.2472     78.84        89
# 724       Taoudenni        ML  22.6783   -3.9836     84.20        10
# 725         Foumban        CM   5.7291   10.9001     69.44        22
#
#          Cloudiness  Wind Speed  Current Weather
# City_ID
# 707              87        8.77  overcast clouds
# 709               0       13.80        clear sky
# ...

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Current Weather", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                   City   Country  Max Temp  Current Weather      Lat  \
# City_ID
# 0               Atuona        PF     78.57       light rain  -9.8000
# 4               Liwale        TZ     69.37    moderate rain  -9.7667
# 6          East London        ZA     72.21    broken clouds -33.0153
# 7        Mar Del Plata        AR     82.42        clear sky -38.0023
# 10          Oranjemund  Namimbia     65.37    broken clouds -28.5500
# 11           Busselton        AU     66.09    broken clouds -33.6500
# 13              Moerai        PF     80.89    broken clouds -22.4333
# 15          Butaritari        KI     81.39       light rain   3.0707
# 20               Vaini        TO     80.76    broken clouds -21.2000
# 22              Avarua        CK     84.25  overcast clouds -21.2078
#
#               Lng Hotel Name
# City_ID
# 0       -139.0333
# 4         37.9333
# 6         27.9116
# 7        -57.5575
# 10        16.4333
# 11       115.3333
# 13      -151.3333
# 15       172.7902
# ...

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    
    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    
    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
hotel_df.head()
# Out:
#                   City   Country  Max Temp Current Weather      Lat       Lng  \
# City_ID
# 0               Atuona        PF     78.57      light rain  -9.8000 -139.0333
# 4               Liwale        TZ     69.37   moderate rain  -9.7667   37.9333
# 6          East London        ZA     72.21   broken clouds -33.0153   27.9116
# 7        Mar Del Plata        AR     82.42       clear sky -38.0023  -57.5575
# 10          Oranjemund  Namimbia     65.37   broken clouds -28.5500   16.4333
#
#                        Hotel Name
# City_ID
# 0                     Villa Enata
# 4                    Samoma lodge
# 6                         Tu Casa
# 7        Gran Hotel Mar del Plata
# 10           The Fisherman's Cove

# %%
hotel_df.count()
# Out:
# City               323
# Country            323
# Max Temp           323
# Current Weather    323
# Lat                323
# Lng                323
# Hotel Name         323
# dtype: int64

# %%
# 7. Drop the rows where there is no Hotel Name.
# N/A

# %%
# 8a. Create the output File (CSV)
output_data_file = "weatherPy_vacation.csv"

# 8b. Export the City_Data into a csv
hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """

"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 

# 11b. Display the figure
