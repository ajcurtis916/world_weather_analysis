# %%
# Import the random module.
import random

# %%
#random float between 0 - 1
random.random()
# Out:
# 0.9123644765773636

# %%
#random whole number bw specified range
random.randint(-90,90)
# Out:
# -23

# %%
#combine to output random float bw specified range
random_number=random.randint(-90,89)+random.random()
random_number
# Out:
# -34.55085231537074

# %%
#for loop to create 10 random floats
x=1
latitudes=[]
while x<11:
    random_lat=random.randint(-90,89)+random.random()
    latitudes.append(random_lat)
    x+=1

# %%
latitudes
# Out:
# [-66.80786065841946,
#  -43.21959807375007,
#  -36.00245563457951,
#  45.84196838191468,
#  36.78727915129685,
#  -35.23421739222559,
#  -55.22336147541141,
#  21.171453040918443,
#  30.56774116729719,
#  -50.657368965009425]

# %%
random.randrange(-90,90,step=3)
# Out:
# -12

# %%
#import NumPy module
import numpy as np

# %%
np.random.uniform(-90.000,90.000)
# Out:
# 30.147180388995977

# %%
#outputting multiple floats
np.random.uniform(-90,90,size=50)
# Out:
# array([ 33.80301595,  -3.10719055,  18.48223791,  71.54876175,
#        -37.52688048,  60.37342281, -76.91664423,  67.82471545,
#         76.37354764,  80.26215697,  44.85562216,  -1.94811145,
#         53.66055545,  10.17920546,  42.31293195,  23.34922799,
#          3.14152392,  84.41885587, -21.21294181, -17.23459153,
#         24.70009727, -89.30695526,  81.04015181, -75.17821594,
#         82.40617311, -33.47019784, -66.225973  ,  56.34203629,
#         55.89642843, -35.69469684, -12.45162599,  60.76675619,
#         84.80782882, -84.95485948,  86.48927187, -58.85203571,
#        -75.49789588, -12.28132823, -57.39430826,  74.25814041,
#        -76.86189004, -17.45815854,  72.04100707, -81.23952966,
#        -89.11935732, -32.36846103,  26.38595439, -73.43390065,
#         28.17540208, -67.95981758])

# %%
# Import timeit.
import timeit

# %%
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 33.1 µs ± 683 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 4.26 ms ± 103 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
#refactor while loop to a for loop
def latitudes():
    latitudes=[]
    for lat in range(1500):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
    return latitudes

latitudes()
# Out:
# [43.930903124560785,
#  -27.745445881827447,
#  75.17771739162902,
#  -79.246272493889,
#  77.35672411635967,
#  71.74067655726648,
#  -51.827206789594655,
#  6.127756005061857,
#  38.50481324686147,
#  -2.8297305495117238,
#  -88.5545017119649,
#  -82.887588261537,
#  13.797565077393749,
#  3.5028530729584215,
#  75.32807156655497,
#  -78.87712581124774,
#  67.17868661323978,
#  -81.5342482610062,
#  65.30092408201801,
#  41.70498866076197,
#  42.58459105060535,
#  -49.002318831859206,
#  -18.49227988634665,
#  -33.27280153466692,
#  34.07234948780079,
#  -44.214494573765165,
#  52.384866210586,
#  5.574049547144961,
#  87.36879922101797,
#  25.578798925124453,
#  -9.65092822557926,
#  -30.74823388045262,
#  71.81619489135747,
#  -50.6490638569924,
#  -41.91867883055442,
#  33.48832834563476,
#  14.66624851297238,
#  -9.581520663889403,
#  40.72258227861132,
#  -54.81980317932928,
#  -19.423850963652605,
#  -22.08188385457343,
#  -1.796033540225187,
#  -48.99393059724538,
# ...

# %%
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Create an equal number of latitudes and temperatures.
lats = [42.5, 43.9, 8.1, 36.8, 79.9, 69.1, 25.7, 15.3, 12.7, 64.5]
temps = [80.5, 75.3, 90.9, 90.0, 40.4, 62.3, 85.4, 79.6, 72.5, 72.0]

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(lats, temps)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -0.45x + 92.94
# The p-value is: 0.011

# %%
# Calculate the regression line "y values" from the slope and intercept.
regress_values = [(lat * slope + intercept) for lat in lats]

# %%
# Import Matplotlib.
import matplotlib.pyplot as plt
# Create a scatter plot of the x and y values.
plt.scatter(lats,temps)
# Plot the regression line with the x-values and the y coordinates based on the intercept and slope.
plt.plot(lats,regress_values,"r")
# Annotate the text for the line equation and add its coordinates.
plt.annotate(line_eq, (10,40), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Temp')
plt.show()
